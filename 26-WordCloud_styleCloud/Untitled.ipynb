# %% [raw]
# !pip install stylecloud

# %%
import stylecloud as sc
sc.gen_stylecloud(file_path = 'challenge.txt', output_name = 'ch.png')

# %%
from IPython.display import Image
Image(filename = 'ch.png')

# %%
import stylecloud as sc
sc.gen_stylecloud(file_path = 'challenge.txt',
                  icon_name = 'fas fa-dog',
                  palette = 'colorbrewer.diverging.Spectral_11',
                  background_color = 'black',
                  gradient = 'horizontal',
                  output_name = 'ch5.png')

# %%
from IPython.display import Image
Image(filename = 'ch5.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                  icon_name = 'fas fa-cat',
                  palette = 'colorbrewer.diverging.Spectral_11',
                  background_color = 'white',
                  gradient = 'horizontal',
                  output_name = 'ch5.png')

# %%
from IPython.display import Image
Image(filename = 'ch5.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                  icon_name = 'fas fa-apple-alt',
                  palette = 'colorbrewer.diverging.Spectral_11',
                  background_color = 'white',
                  gradient = 'horizontal',
                  output_name = 'ch6.png')

# %%
Image(filename = 'ch6.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-car',
                 output_name = 'ch7.png')
Image(filename = 'ch7.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt', icon_name = 'fas fa-fighter-jet', output_name = 'ch8.png')
Image(filename = 'ch8.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-rocket',
                 output_name = 'ch9.png')
Image(filename = 'ch9.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-heart',
                 output_name = 'ch10.png')
Image(filename = 'ch10.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-star-and-crescent',
                 output_name = 'ch10.png')
Image(filename = 'ch10.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-fire-extinguisher',
                 output_name = 'ch11.png')
Image(filename = 'ch11.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-lemon',
                 output_name = 'ch12.png')
Image(filename = 'ch12.png')

# %%
sc.gen_stylecloud(file_path = 'challenge.txt',
                 icon_name = 'fas fa-cloud-sun-rain',
                 output_name = 'ch13.png')
Image(filename = 'ch13.png')

# %% [markdown]
# ### Wordcloud

# %% [raw]
# pip install stop_words

# %%
from stop_words import get_stop_words
stop_words = get_stop_words('english')

# %%
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
my_mask = np.array(Image.open('cloud3.png'))
wc = WordCloud(background_color = 'white',
              mask = my_mask,
              collocations = False,
              width = 600,
              height = 300,
              contour_color = 'black',
              stopwords = stop_words,
              contour_width = 3)

# %%
with open('challenge.txt', 'r') as txt_file:
    texto = txt_file.read()
wc.generate(texto)

# %%
plt.figure(figsize = (20, 10))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
wc.to_file('wordcloud.png')
plt.show()
